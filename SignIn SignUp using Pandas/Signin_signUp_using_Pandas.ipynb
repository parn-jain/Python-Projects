# %%
# import vonage
# client = vonage.Client(key="6c46ac7f", secret="6glv12YLA6lcmMQ5")
# sms = vonage.Sms(client)


# responseData = sms.send_message(
#     {
#         "from": "Vonage APIs",
#         "to": "9981974407",
#         "text": "Ha bhaiiii",
#     }
# )
# print(responseData)

# if responseData["messages"][0]["status"] == "0":
#     print("Message sent successfully.")
# else:
#     print(f"Message failed with error: {responseData['messages'][0]['error-text']}")

# %%
# d ={'admin':'Pj@123456'}
# num = {'+919399374451':'admin'}
# SQ = {'what is your hobby ?':'2d animation'}
# print(SQ['what is your hobby ?'])
# import random

# %%
# x = d['admin']
# print(x)

# %%
# def checkPasswordStrength():
#     while 1:
#         flag = 0
#         passUp = input("Enter a strong password")
#         if(not(passUp.isdigit())):
#             flag = flag+1
#         if(not(passUp.isalpha())):
#             flag = flag + 1
#         if(not(passUp.isalnum())):
#             flag = flag + 1
#         if(flag==3):
#             return passUp
# def forgotPass(userIn):
#     flag2 = 3
#     while flag2:
#         t = input("what is your hobby ?").lower()
#         if(t==SQ['what is your hobby ?']):
            
#             while 1:
#                 s = checkPasswordStrength()
#                 d.update({userIn:s})
#                 return s
#         else:
#             flag2 = flag2 - 1 
#             print("incorrect , please try again")
#     return 'Failed'


# def SequrityQuest():
#     f = input('What is your hobby')
#     SQ.update({'what is your hobby ?':f})
#     return 'SQ added'
    
# def OTPgenerator():
#     otp = random.randint(1000,9999)
#     return otp
# def numSignUp():
#     x = input('enter mobile number')
#     return x

# # def verifyOTP(randOTP):
# #     x = input("enter the OTP you got in SMS on registered mobile number")
# #     if(x==randOTP):
        



# # def numSignIn(userIn):            #verifyUser
# #     flag = True
# #     while(flag):
# #         inputMobNo = input('enter your registered mobile number')
# #         if((inputMobNo in num) and num[inputMobNo]==userIn):
# #             OTP = OTPgenerator()
# #             print(OTP)
# #             import vonage
# #             client = vonage.Client(key="6c46ac7f", secret="6glv12YLA6lcmMQ5")
# #             sms = vonage.Sms(client)


# #             responseData = sms.send_message(
# #                 {
# #                     "from": "Vonage APIs",
# #                     "to": inputMobNo,
# #                     "text": OTP,
# #                 }
# #             )
# #             if responseData["messages"][0]["status"] == "0":
# #                 print("Message sent successfully.")
# #                 return OTP;
# #             else:
# #                 print(f"Message failed with error: {responseData['messages'][0]['error-text']}")
# # #     return OTP;







# def numSignIn(userIn):            #verifyUser
#     flag = True
#     while(flag):
#         inputMobNo = input('enter your registered mobile number')
#         if((inputMobNo in num) and num[inputMobNo]==userIn):
#             OTP = OTPgenerator()
#             print(OTP)
# #             import os
# #             from twilio.rest import Client
# #             # Set environment variables for your credentials
# #             # Read more at http://twil.io/secure
# #             account_sid = "AC63cfea0614536b35e88db7ddc1d56648"
# #             auth_token = "cf30c91660adaa3379db5c728645f634"
# #             client = Client(account_sid, auth_token)
# #             message = client.messages.create(
# #               body=OTP,
# #               from_="+14406893463",
# #               to=inputMobNo
# #             )
# #             print(message.sid)
# #             flag=False
# #             print("this is from return OTP")
#             return OTP;







        
# def VerifyOTP(abcd,userIn):       #abcd is the return value of numSignIn
#     x = int(input("enter the OTP you get on your phone"))
#     if(x == abcd):
#         while 1:
#             s = checkPasswordStrength()
#             d.update({userIn:s})
#             print("checked")
#             return True
#     return False

        
# def ResetPass(userIn):
#     x = input('''seems like you forgot your password to reset you password
#             press 1 for OTP method
#             press 2 for Security Question Method''')
#     if(x=='2'):
#         forgotPass(userIn)
#         signIn()
#     if(x=='1'):
#         abcd = numSignIn(userIn)
#         if VerifyOTP(abcd,userIn):
#             signIn()
#             return 'Successfull'
#         else:
#             return 'Failed'

# %%
# def signUp():
#     while 1:
#         userUp = input('Enter a Username: ').lower()
#         if userUp =='0':
#             return 'Failed'
#         if userUp not in d:
#             passUp = checkPasswordStrength()
#             st1 = 3
#             while st1:
#                 passUp2 = input("Re-enter your password")
#                 if(passUp==passUp2):
#                     d.update({userUp:passUp})
#                     sqAns = SequrityQuest()
#                     Unum = numSignUp()
#                     num.update({Unum:userUp})
#                     print('Sign Up successfull')
#                     signIn()
#                     return True
#                 else:
#                     print("Password does not match , please Try again")
#             return 'Failed'
#         else:
#             print("""Username already exists... Plz try another Username
#             Press 0 to exit 
#             Or """)
# #         SequrityQuest()
    
            
            
# # userIn = 'pass'
# print(d.items())
# def signIn():
#     flag1 = 3
#     while flag1:
#         userIn = input('Enter you user Name')
#         if(userIn in d):
#             flag1 = 3
#             while flag1:
#                 passIn = input("enter your password")
#                 if(passIn == d[userIn]):
#                     print(f" Welcome {userIn}")
#                     return userIn
#                 else:
#                     print("invlaid password")
#                     flag1 = flag1-1
# #             return 'failed'
# #             passIn = forgotPass(userIn)
# #             abcd = numSignIn(userIn)
# #             if VerifyOTP(abcd,userIn):
# #                 return 'Successfull'
# #             else:
# #                 return 'Failed'
#             ResetPass(userIn)
                
    
#         else:
#             flag1 = flag1 - 1
#     return False

# %%
# def main():
#     while 1:
#         mode = input('''choose mode:
#         Press 1 to SignUp
#         Press 2 to SignIn
#         Press 0 to exit
#         : ''')
#         if(mode=='1'):
#             signUp()
# #             break
#             return 'Done'
# #             print('signUp')
#         elif(mode=='2'):
#             signIn()
# #             break
#             return True
#         elif(mode=='0'):
#             print("Thankyou for using our service")
#             break
#         else:
#             print("enter valid input")
# main()

# %%
import pandas as pd
# k = pd.read_csv(r'C:\CSV files\SignInUp.csv')
# k

# %%
d ={'admin':'Pj@123456'}
num = {'+919399374451':'admin'}
SQ = {'what is your hobby ?':'2d animation'}

data = {'UserName':['admin'],
        'pass':['Pj@123456'],
        'SA':['2D animation'],
       'num':['+919399374451']
       }

df = pd.DataFrame(data)
df
# Out:
#   UserName       pass            SA            num
# 0    admin  Pj@123456  2D animation  +919399374451

# %%
# df.to_csv('userData.csv',index = False)
k = pd.read_csv(r'userData.csv')

# %%
# data2 = ['Parn','Hello@123','+919399374450','coding']
# k.loc[1] = data2
# k
# k.drop(index = 1, inplace = True)
k
# Out:
#        UserName          pass            SA            num
# 0         admin     Pj@123456  2D animation   919399374451
# 1          parn           asd           sdf            sdf
# 2          asdf           sad          fsad           fsad
# 3         wesfd        awefsd         wesfd        ewrafsd
# 4          ersd          erfd          erdf   919399374451
# 5  919399374451  919399374451  919399374451  sgvsfbsrsfdbg

# %%
# UserNames = list(k['UserName'])
# UserNames
# nums = list(k['num'])
# nums
# x= k.index[-1]
# x
indexes = list(k.index)
indexes
# p = pd.read_csv()
t = pd.read_csv(r'userData.csv',index_col = 'UserName')
o =list(t.index)
d = list(t.loc['admin'])
t
# Out:
#                       pass            SA            num
# UserName
# admin            Pj@123456  2D animation   919399374451
# parn                   asd           sdf            sdf
# asdf                   sad          fsad           fsad
# wesfd               awefsd         wesfd        ewrafsd
# ersd                  erfd          erdf   919399374451
# 919399374451  919399374451  919399374451  sgvsfbsrsfdbg

# %%
def NsignUp():
#     UserNames = list(t.index)
    UserNames = list(k['UserName'])
    UserNames
    nums = list(k['num'])
    nums
    l = []
    j = 0
    flag = True
    flag2 = True
    while flag:
        x = input('Enter your user Name')
        if(x in UserNames):
            print('UserName taken , try another one')
            continue
        else:
            l.append(x)
            y = input('Enter a strong password')
            l.append(y)
            z = input('Enter security question')
            l.append(z)
            if(j>0):
                break
            while flag2:
                num = input('Enter the mobile number')
                if(num in nums):
                    print('number already used , use another number')
                    continue
                else:
                    l.append(num)
                    j = j+1
                    k.loc[k.index[-1]+1] = l
                    flag = False
                    k.to_csv('userData.csv',index = False)
                    return k
    l
# NsignUp()
# o =list(t.index)
# d = list(t.loc['admin'])
# t

def NsignIN():
    flag = True
    flag2 = True
    while flag:
        x = input('Enter you user name')
        if(x in list(t.index)):
            while flag2:
                y = input('enter you password')
                if(y in list(t.loc[x])):
                    print("logged in successfully")
                    return 'Successful'

                else:
                    print('Incorrect password plz try again')
                    continue
        else:
            print('Username not found , enter a valid user name')
            continue
            
NsignIN()
# Out:
# Enter you user nameparn
# enter you passwordsfd
# Incorrect password plz try again
# enter you passwordasd
# logged in successfully
# 'Successful'

# %%
# k
# j = pd.read_csv(r'userData.csv')
# j
# k.drop(index = 2,inplace = True)

k
# Out:
#        UserName          pass            SA            num
# 0         admin     Pj@123456  2D animation   919399374451
# 1          parn           asd           sdf            sdf
# 2          asdf           sad          fsad           fsad
# 3         wesfd        awefsd         wesfd        ewrafsd
# 4          ersd          erfd          erdf   919399374451
# 5  919399374451  919399374451  919399374451  sgvsfbsrsfdbg

# %%
index = k.loc[df['UserName'] == 'admin'].index
print(index)
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 index = k.loc[df['UserName'] == 'admin'].index
#       2 print(index)
#
# File C:\Python compiler\lib\site-packages\pandas\core\indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File C:\Python compiler\lib\site-packages\pandas\core\indexing.py:1292, in _LocIndexer._getitem_axis(self, key, axis)
#    1290     return self._get_slice_axis(key, axis=axis)
#    1291 elif com.is_bool_indexer(key):
# -> 1292     return self._getbool_axis(key, axis=axis)
#    1293 elif is_list_like_indexer(key):
#    1294
#    1295     # an iterable multi-selection
#    1296     if not (isinstance(key, tuple) and isinstance(labels, MultiIndex)):
#
# File C:\Python compiler\lib\site-packages\pandas\core\indexing.py:1091, in _LocationIndexer._getbool_axis(self, key, axis)
#    1087 @final
#    1088 def _getbool_axis(self, key, axis: int):
#    1089     # caller is responsible for ensuring non-None axis
#    1090     labels = self.obj._get_axis(axis)
# -> 1091     key = check_bool_indexer(labels, key)
#    1092     inds = key.nonzero()[0]
#    1093     return self.obj._take_with_is_copy(inds, axis=axis)
#
# File C:\Python compiler\lib\site-packages\pandas\core\indexing.py:2552, in check_bool_indexer(index, key)
#    2550 indexer = result.index.get_indexer_for(index)
#    2551 if -1 in indexer:
# -> 2552     raise IndexingError(
#    2553         "Unalignable boolean Series provided as "
#    2554         "indexer (index of the boolean Series and of "
#    2555         "the indexed object do not match)."
#    2556     )
#    2558 result = result.take(indexer)
#    2560 # fall through for boolean
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match).
